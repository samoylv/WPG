# %% [markdown]
# # Change-Log

# %% [markdown]
# ## Changes to the Wavefront Class
#
# ### Quality of Life Improvements
# - 1
# - 2
# - 3

# %%
from matplotlib import pyplot as plt
plt.plot()
# Out:
# []
